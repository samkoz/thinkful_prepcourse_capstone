# %% [markdown]
# # Analysis of the Medicare Provider Charge Inpatient Dataset from 2014
#
#
# ## Motivation for this analysis:
# The American Healthcare system is in disarray. Despite providing some of the most technologically sophisticated care in the world, our country is paying exorbitant amounts for mediocre health outcomes. Hiding within these aggregate summary statements are the individuals suffering from this system’s consequences - the patients and families who are bankrupted by excessive hospital bills or financially hamstrung by the costs of managing a chronic disease.
#
# Answering why healthcare costs so much is a difficult task. On an individual level, the demand for healthcare is fairly inelastic; there is no price too great a family or person might pay to avoid catastrophic or fatal illness. Most Americans now have health insurance, which shields consumers from the true cost of health services by paying large portions of most medical expenses. In America, there are public insurers (such as Medicare and Medicaid) and private insurers. While Medicare pays providers a flat fee, private insurance companies negotiate with individual hospital providers to determine what percent of the hospital charge they will pay. The relative bargaining power between the these insurers and providers plays a large role in determining the final cost.
#
# In 2013, The Center for Medicare and Medicaid Services began releasing annual datasets on the average charges health providers requested in treating medicare payments. These data revealed the ‘rate card’ (i.e. the full charge before insurance company discounts) each hospital charges for common procedures and services reimbursed by medicare. The data was shocking in its variability and seeming arbitrariness; there seemed to be no rational explanation for the range of charges hospitals made for the same procedures.
#
# I was drawn to this dataset as I believe it has the potential to offer insight into why healthcare is such a frustrating issue in the United States. As a future physician, I feel a better understanding of how the healthcare system works will enable me to take better care of my patients and advocate for policy changes that improve public health.

# %% [markdown]
# ## A description of the Datasets
#
# Three datasets were used for the analysis. The main medicare charge dataset was obtained from the [Centers from Medicare and Medicaid Services (CMS)](https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/Inpatient2011.html). According to the descrption on the CMS site, this dataset "consistes of hospital-specific charges for the more than 3,000 U.S. hospitals that receive Medicare Inpatient Prospective Payment System (IPPS) payments for discharges, paid under Medicare based on a rate per discharge using the Medicare Severity Diagnosis Related Group (MS-DRG) for Fiscal Year (FY) 2014." I was most interested in the "Average Covered Charges" column, i.e. the amount individual providers requested Medicare reimburse them for each hospitalization of a given diagnosis (DRG). Included in the dataset was also geographic information, such as the state and Hospital Referral Region (HRR) where each provider was located. An HRR, according to the Dartmouth Atlas of Healthcare, "represents regional health care markets for tertiary medical care that generally require the services of a major referral center", i.e. the region within which all smaller hospitals with a more narrow range of clinical services refer their patients to larger hopsitals that can treat more complicated patients.
#
# The second dataset consistend of Medicare Fee-for-Service Enrollment by State and Hospital Referral Region. As will be seen below, knowing medicare enrollment rates by state allow us to assess whether the average covered charge each hospital levied against medicare was related to the number of medicare enrollee's in their area.
#
# The third dataset, obtained from the [Open Payments Site](https://www.cms.gov/OpenPayments/About/Resources.html), contains a list of teaching hopsitals, i.e. healthcare institutions where medical students and residents are trained. This dataset, in tandem with the Medicare Charge data, allows us to assess whether healthcare is more expensive at teaching hopsitals (as is commonly believed) than at non-teaching hopsitals.
#
# Representative samples for each dataset are displayed immediately below.

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import os
import scipy.stats as stats 

# medicare charge data from CMS
medicare_charge_data = pd.read_csv("Medicare_Provider_Charge_Inpatient_DRGALL_FY2014.csv")
df = medicare_charge_data

# Medicare Fee For Service Enrollment by State
HRR_names_and_beneficiaries = pd.read_excel("Medicare_Fee-For-Service_Enrollment_by_State_and_HRR_CY2014.xlsx", sheetname=3, skiprows=5)

# list of teaching hospitals
teaching_hospitals = pd.read_excel("2015-Reporting-Year-Teaching-Hospital-[October-2014].xlsx", skiprows=4)

# convenience variables
state_list = df['Provider State'].unique() # total of 51 (includes DC)
DRG_list = df['DRG Definition'].unique() # total of 564
provider_list = df['Provider Id'].unique() # total of 3276
hrr = 'Hospital Referral Region (HRR) Description'
acc = 'Average Covered Charges'
drg_def = "DRG Definition"

# %% [markdown]
# #### Representative Sample from the primary dataset of Medicare Charges from 2014 from the CMS website

# %%
df[:3]
# Out:
#                                       DRG Definition  Provider Id  \
# 0  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        10033
# 1  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30103
# 2  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50108
#
#                     Provider Name   Provider Street Address Provider City  \
# 0  UNIVERSITY OF ALABAMA HOSPITAL     619 SOUTH 19TH STREET    BIRMINGHAM
# 1            MAYO CLINIC HOSPITAL  5777 EAST MAYO BOULEVARD       PHOENIX
# 2         SUTTER GENERAL HOSPITAL             2801 L STREET    SACRAMENTO
#
#   Provider State  Provider Zip Code  \
# 0             AL              35233
# 1             AZ              85054
# 2             CA              95816
#
#   Hospital Referral Region (HRR) Description  Total Discharges  \
# 0                            AL - Birmingham                13
# 1                               AZ - Phoenix                20
# 2                            CA - Sacramento                25
#
#    Average Covered Charges  Average Total Payments  Average Medicare Payments
# 0              1172866.385             251876.3077                244457.9231
# 1               437531.300             240422.8000                133509.5500
# 2               815674.120             233197.4800                221681.8000

# %% [markdown]
# #### Representative Sample of The Medicare Fee For Service Enrollment by State and HRR from the CMS site

# %%
HRR_names_and_beneficiaries.head()
# Out:
#    HRR Code         HRR Name  Medicare Beneficiaries Enrolled in FFS Part A  \
# 0       NaN    United States                                       36684241
# 1       1.0  AL - Birmingham                                         332912
# 2       2.0      AL - Dothan                                          68120
# 3       5.0  AL - Huntsville                                         100313
# 4       6.0      AL - Mobile                                         108930
#
#    Medicare Beneficiaries Enrolled in FFS Part B
# 0                                       33645448
# 1                                         313260
# 2                                          65367
# 3                                          93922
# 4                                         102153

# %% [markdown]
# #### Representative Sample of the 2015 Reporting Year (i.e. 2014) For Teaching Hospitals from the Open Payment Website

# %%
teaching_hospitals[:3]
# Out:
#          TIN                     Hospital Name  \
# 0  920016429  PROVIDENCE ALASKA MEDICAL CENTER
# 1  461468253      CALLAHAN EYE FOUNDATION HOSP
# 2  636001579       COOPER GREEN MERCY HOSPITAL
#
#                      PECOS Legal Business Name             Street Address  \
# 0    Providence Health & Services - Washington      3200 PROVIDENCE DRIVE
# 1  Callahan Eye Hospital Health Care Authority  1720 UNIVERSITY BOULEVARD
# 2                  Jefferson County Commission    1515 SIXTH AVENUE SOUTH
#
#           PO Box        City State   Zip Code      Street Address 1  \
# 0  PO BOX 196604   ANCHORAGE    AK      99519    3200 Providence Dr
# 1            NaN  BIRMINGHAM    AL      35233  1720 University Blvd
# 2            NaN  BIRMINGHAM    AL      35233        1515 6th Ave S
#
#   Street Address 2      City.1 State.1  Zip Code
# 0              NaN   Anchorage      AK     99508
# 1        Suite 500  Birmingham      AL     35233
# 2              NaN  Birmingham      AL     35233

# %% [markdown]
# ## A description of the data on the National Level
#
# Conatined within these files are hundreds of diagnoses being charged by thousands of hospitals distributed accross 50 states (+ Washington D.C) at different types of institutions (teaching vs. non-teaching) with different medicare populations within different regional private insurance markets. With so many potential avenues of exploration, it can be challenging to focus one's analysis sufficently to derive interesting conclusions. We will attempt to do so by starting broadly at the national level and then narrowing our analysis to the most popular DRG's (by number of total discharges billed with that diagnosis nationally).

# %% [markdown]
# #### Here, a function is defined that takes a DRG and location and returns useful summary statistics about  that DRG at either the national or state level.

# %%
df_description_by_DRG = df.groupby('DRG Definition').describe().drop(['Provider Id', 'Provider Zip Code'], 1)
df_description_by_DRG_by_state = df.groupby(['DRG Definition', 'Provider State']).describe().drop(['Provider Id', 'Provider Zip Code'], 1)

# %%
def DRG_state_lookup(DRG, location):
    """Paremeters: DRG = to a DRG w/in the above df's, and Location = either a state or 'US'
    Returns the df.describe() row for the above groupby df's."""
    try: 
        if location == 'US':
            return df_description_by_DRG[df_description_by_DRG.index.get_level_values(0).str.contains(DRG)]
        else: 
            state = location
            return df_description_by_DRG_by_state[
                (df_description_by_DRG_by_state.index.get_level_values(0).str.contains(DRG)) & 
                (df_description_by_DRG_by_state.index.get_level_values(1) == state)]
    except KeyError as e:
       print("error: check your inputs. ")

# %% [markdown]
# #### As an example, here is a summary of DRG - 004 both nationally States and in Califorinia.

# %%
# National Data
DRG_state_lookup('004', location='US')
# Out:
#                                                           Average Covered Charges  \
# DRG Definition
# 004 - TRACH W MV 96+ HRS OR PDX EXC FACE, MOUTH... count             5.750000e+02
#                                                    mean              3.199283e+05
#                                                    std               1.850113e+05
#                                                    min               6.036871e+04
#                                                    25%               2.006250e+05
#                                                    50%               2.719623e+05
#                                                    75%               3.940423e+05
#                                                    max               1.420373e+06
#
#                                                           Average Medicare Payments  \
# DRG Definition
# 004 - TRACH W MV 96+ HRS OR PDX EXC FACE, MOUTH... count                 575.000000
#                                                    mean                72172.939143
#                                                    std                 25625.880543
#                                                    min                 37237.315790
#                                                    25%                 55374.520190
#                                                    50%                 65189.818180
#                                                    75%                 81871.754465
#                                                    max                287217.288900
#
#                                                           Average Total Payments  \
# DRG Definition
# 004 - TRACH W MV 96+ HRS OR PDX EXC FACE, MOUTH... count              575.000000
#                                                    mean             79539.612315
#                                                    std              28759.775715
#                                                    min              41122.944440
#                                                    25%              59856.666665
#                                                    50%              71838.400000
#                                                    75%              91094.196970
#                                                    max             298575.955600
#
#                                                           Total Discharges
# DRG Definition
# 004 - TRACH W MV 96+ HRS OR PDX EXC FACE, MOUTH... count        575.000000
#                                                    mean          20.476522
#                                                    std           11.529196
#                                                    min           11.000000
#                                                    25%           13.000000
#                                                    50%           16.000000
#                                                    75%           24.000000
#                                                    max           96.000000

# %%
# California Data
DRG_state_lookup('004', 'CA')
# Out:
#                                                                          Average Covered Charges  \
# DRG Definition                                     Provider State
# 004 - TRACH W MV 96+ HRS OR PDX EXC FACE, MOUTH... CA             count             6.000000e+01
#                                                                   mean              5.887694e+05
#                                                                   std               2.788728e+05
#                                                                   min               2.208537e+05
#                                                                   25%               3.927383e+05
#                                                                   50%               5.047612e+05
#                                                                   75%               7.370750e+05
#                                                                   max               1.420373e+06
#
#                                                                          Average Medicare Payments  \
# DRG Definition                                     Provider State
# 004 - TRACH W MV 96+ HRS OR PDX EXC FACE, MOUTH... CA             count                  60.000000
#                                                                   mean                99957.191559
#                                                                   std                 31263.531568
#                                                                   min                 59034.333330
#                                                                   25%                 80485.887360
#                                                                   50%                 90953.787880
#                                                                   75%                106935.309750
#                                                                   max                208698.842100
#
#                                                                          Average Total Payments  \
# DRG Definition                                     Provider State
# 004 - TRACH W MV 96+ HRS OR PDX EXC FACE, MOUTH... CA             count               60.000000
#                                                                   mean            104880.581074
#                                                                   std              35891.605550
#                                                                   min              60552.600000
#                                                                   25%              82647.900625
#                                                                   50%              93663.380340
#                                                                   75%             113179.053550
#                                                                   max             228170.684200
#
#                                                                          Total Discharges
# DRG Definition                                     Provider State
# 004 - TRACH W MV 96+ HRS OR PDX EXC FACE, MOUTH... CA             count         60.000000
#                                                                   mean          14.900000
#                                                                   std            4.057636
#                                                                   min           11.000000
#                                                                   25%           12.000000
#                                                                   50%           13.500000
#                                                                   75%           17.000000
#                                                                   max           28.000000

# %% [markdown]
# ## Q1: How does the cost of healthcare vary by state?

# %% [markdown]
# ### Visualizing the average charge requested from Medicare for a hospitalization
#
# A box plot of the average charge for a given hospital stay (as measured by total discharges across all DRG's) per state is useful in gauging how the cost of healthcare varies by state.

# %%
# calculating average cost for each hospitalization 
# (sum(avg cost per DRG * total discharges per DRG) / total discharges) per institution
# and creating a column of it in a copied dataframe to graph

df_total_charges = df
df_total_charges["Total_Charge"] = df_total_charges[acc] * df_total_charges['Total Discharges']
df_total_charges_g = df_total_charges.groupby(['Provider State', 'Provider Id']).agg(
    {"Total_Charge" : np.sum, "Total Discharges" : np.sum})
df_total_charges_g['Avg_Charge_per_Discharge'] = df_total_charges_g.Total_Charge / df_total_charges_g['Total Discharges']

# %% [markdown]
# #### Box plot of the Average Charge per Hospitalization per State

# %%
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 18}

# this seems to reset the font settings for all of matplotlib
# look into this more
plt.rc('font', **font)

data_to_plot = [df_total_charges_g.loc[state, :]['Avg_Charge_per_Discharge'] for state in state_list]
fig = plt.figure(1, figsize=(20,10))
ax = fig.add_subplot(111)
bp = ax.boxplot(data_to_plot, labels=state_list)
plt.title("Box Plot of Average Charge per Hospitalization per State")
plt.xticks(rotation='vertical')
plt.ylabel("Average Charge ($)")
plt.xlabel("State")
plt.tight_layout()
plt.show()

# %% [markdown]
# As the above graph demonstrates, there is substantial variation between states on the average total chage to medicare for each hospitalization. However, this is a rather superficial assesment of the cost given how different each region is in terms of the conditions they treat, populaton density, teaching vs. non-teaching institutions and number of medicare beneficiaries. Comparing the average charge requested from medicare for a particular DRG across states may be more enlightening.

# %% [markdown]
# #### Box plot of the average cost in each state for the nation's most popular DRGs (by total number of discharges)

# %%
df_DRG_counts = df.groupby('DRG Definition').agg({'Total Discharges' : np.sum})
top_five_DRGs = df_DRG_counts.sort_values('Total Discharges', ascending=False)[:5].index

# %%
ind = 1
for DRG in top_five_DRGs:

    data_to_plot = [df[(df['DRG Definition'] == DRG) & (df['Provider State'] == state)][acc] for state in state_list]
    fig = plt.figure(1, figsize=(15,45))
    ax = fig.add_subplot(5, 1, ind)
    bp = ax.boxplot(data_to_plot, labels=state_list)
    plt.title("Box Plot of Average Charge for DRG #{} per State".format(DRG.split(' ')[0]))
    plt.xticks(rotation='vertical')
    plt.ylabel("Average Charge ($)")
    plt.xlabel("State")
    plt.tight_layout()

    ind += 1
print("Top five DRGs:")
for DRG in top_five_DRGs:
    print(DRG)
print()
plt.show()
# Out:
# Top five DRGs:
# 470 - MAJOR JOINT REPLACEMENT OR REATTACHMENT OF LOWER EXTREMITY W/O MCC
# 871 - SEPTICEMIA OR SEVERE SEPSIS W/O MV 96+ HOURS W MCC
# 291 - HEART FAILURE & SHOCK W MCC
# 292 - HEART FAILURE & SHOCK W CC
# 392 - ESOPHAGITIS, GASTROENT & MISC DIGEST DISORDERS W/O MCC

# %% [markdown]
# The above boxplots show not only that there is substantial variation of medicare charges accross states for the above DRG's, but that state's relative costs when compared to each othe remains consistent (at least for the DRG's assessed). Further analysis would be necessary to see whether that generally holds for all DRG's.

# %%
# reset matplotlib fonts
plt.rcdefaults()

# %% [markdown]
# ## Q2: Which hospital charges the least for each DRG? The most?

# %% [markdown]
# Given the variation in hospital charges, and the prospect that certain patients may be faced with  radically different hopsital bills depending on their insurance, it is valuable for healthcare consumers to know where the least and most expensive care can be purchased. Directly below is a function I defined that provides that information, either nationally or by state.

# %%
def min_max_cost_for_DRG(df, DRG, state):
    """Takes df, DRG (though this can just be an abbreviated DRG in string form, e.g. 014) 
    and two letter state abbreviation or 'US' as parameters. Will then print the Cheapest
    provider and most expensive provider in either the state and US of that specified 
    procedure. The df can be raw data if desired, or can be the min_max df
    
    Note, the dataset does not include all DRG numbers (e.g. 018). If it is not
    within the dataframe, then the function will display all available DRGs
    and notify you"""
    
    most_expensive = df.groupby(['Provider State', 'DRG Definition'])['Average Covered Charges'].transform(max)
    least_expensive = df.groupby(['Provider State', 'DRG Definition'])['Average Covered Charges'].transform(min)
    df_copy = df
    df_copy['most_expensive'] = most_expensive.values
    df_copy['least_expensive'] = least_expensive.values
    min_max_df = df_copy[(df_copy[acc] == df_copy['most_expensive']) | (df_copy[acc] == df_copy['least_expensive'])]
    
    try: 
        if state != 'US':
            prov_df = df_copy[(df_copy['Provider State'] == state) & (df_copy['DRG Definition'].str.contains(DRG))]
            min_prov = prov_df[prov_df[acc]==prov_df['least_expensive']]
            max_prov = prov_df[prov_df[acc]==prov_df['most_expensive']]
        else: 
            us_df = df_copy[df_copy['DRG Definition'].str.contains(DRG)]
            max_cost, min_cost = us_df[acc].max(), us_df[acc].min()
            min_prov = us_df[us_df[acc] == min_cost]
            max_prov = us_df[us_df[acc] == max_cost]
        dx = min_prov['DRG Definition'].values[0]
        min_prov_p, min_prov_a = min_prov['Provider Name'].values[0], min_prov[acc].values[0]
        max_prov_p, max_prov_a = max_prov['Provider Name'].values[0], max_prov[acc].values[0]


        x_prov_a = max_prov['Provider Name'].values[0], max_prov[acc].values[0]
        print("Procedure: ", dx)
        print("Cheapest Provider in {}: {} -- ${}".format(state, min_prov_p, min_prov_a))
        print("Most Expensive Provider in {}: {} -- ${}".format(state, max_prov_p, max_prov_a))
    except IndexError:
        print(DRG_list)
        print()
        print('This DRG is not present in the dataset. See above for the available DRG\'s and try again.')

# %% [markdown]
# #### Example fuciton call using DRG 014 - Allogenic Bone Marrow Transplant, both nationally and in the state of California

# %%
# this is a function call of the function above
min_max_cost_for_DRG(df, '014', 'US')
# Out:
# Procedure:  014 - ALLOGENEIC BONE MARROW TRANSPLANT
# Cheapest Provider in US: JOHNS HOPKINS HOSPITAL, THE -- $131667.6923
# Most Expensive Provider in US: STANFORD HOSPITAL -- $702608.3333

# %%
min_max_cost_for_DRG(df, '014', 'CA')
# Out:
# Procedure:  014 - ALLOGENEIC BONE MARROW TRANSPLANT
# Cheapest Provider in CA: RONALD REAGAN U C L A MEDICAL CENTER -- $396286.7273
# Most Expensive Provider in CA: STANFORD HOSPITAL -- $702608.3333

# %% [markdown]
# ## Q3 - Which hospitals are the most expensive for the most DRG's in the country? Least expensive?
#
# Given the above function lets us see which hospitals charge the most and least for each diagnosis, it seemed like an interesting follow up to quantify how frequently these institutions with the highest and lowest fees were either the most or least expensive for a given DRG.

# %%
country_DRG_max_and_min_charges = df
country_DRG_max_and_min_charges['most_expensive'] = df.groupby(['DRG Definition'])['Average Covered Charges'].transform(max)
country_DRG_max_and_min_charges['least_expensive'] = df.groupby(['DRG Definition'])['Average Covered Charges'].transform(min)
min_max_df = country_DRG_max_and_min_charges[(country_DRG_max_and_min_charges[acc] == country_DRG_max_and_min_charges['most_expensive']) | (country_DRG_max_and_min_charges[acc] == country_DRG_max_and_min_charges['least_expensive'])]

idx = min_max_df['most_expensive'] == min_max_df[acc]
max_providers = min_max_df[idx]
idx = min_max_df['least_expensive'] == min_max_df[acc]
min_providers = min_max_df[idx]

max_counts = max_providers.groupby('Provider Name')['Provider Id'].count().sort_values(ascending=False).to_frame()
min_counts = min_providers.groupby('Provider Name')['Provider Id'].count().sort_values(ascending=False).to_frame()

# %% [markdown]
# #### The 10 Institutions that charge the _most_ for the most diagnoses (max_counts representing the number of DRG's they charged the highest value for)

# %%
max_counts[:10]
# Out:
#                                                Provider Id
# Provider Name
# CEDARS-SINAI MEDICAL CENTER                             64
# STANFORD HOSPITAL                                       63
# FLORIDA HOSPITAL                                        29
# CAREPOINT HEALTH - BAYONNE MEDICAL CENTER               21
# CAREPOINT HEALTH-CHRIST HOSPITAL                        20
# NEW YORK-PRESBYTERIAN HOSPITAL                          19
# UNIVERSITY OF CALIFORNIA DAVIS MEDICAL CENTER           18
# UPMC PRESBYTERIAN SHADYSIDE                             17
# UCSF MEDICAL CENTER                                     13
# HAHNEMANN UNIVERSITY HOSPITAL                           13

# %% [markdown]
# #### The 10 Institutions that charge the _least_ for the most diagnoses

# %%
min_counts[:10]
# Out:
#                                                   Provider Id
# Provider Name
# ANNE ARUNDEL MEDICAL CENTER                                33
# JOHNS HOPKINS HOSPITAL, THE                                25
# UNIVERSITY OF MARYLAND ST JOSEPH MEDICAL CENTER            17
# SUBURBAN HOSPITAL                                          17
# MERITUS MEDICAL CENTER                                     16
# CHRISTIANA CARE HEALTH SERVICES, INC.                      15
# UNIVERITY OF MD BALTO WASHINGTON  MEDICAL CENTER           15
# UNIVERSITY OF MARYLAND MEDICAL CENTER                      15
# FLORIDA HOSPITAL                                           15
# MAYO CLINIC HOSPITAL ROCHESTER                             14

# %% [markdown]
# ## Q4: Which is the most expensive tertiary referral center in the country? Which is the least?

# %% [markdown]
# According to Wikipedia, a "tertiary referral hospital (also called a tertiary hospital, tertiary referral center, or tertiary care center, or tertiary center) is a hospital that provides tertiary care, which is health care from specialists in a large hospital after referral from primary care and secondary care."
#
# A quick-and-dirty way to select out tertiary care centers is to limit our analysis to hospitals that performed any organ transplants as transplant services are limited to tertiary care centers. Limiting our analysis to tertiary care centers helps ensure that we are comparing hospitals that charged for the same or similar DRG's. Without doing so, the average of the ACC will be skewed towards hospitals that offered more expensive services.
#
# To determine which hospital is the most and least expensive, we need a good marker of overall hospital cost. The average of the averaged covered charge (i.e. the sum of the average covered charge for each diagnosis divdied by the number of diagnoses) seems reasonable.

# %%
transplant_hospitals = df[df[drg_def].str.contains("TRANSPLANT")]['Provider Id'].unique()
transplant_hospitals_df = df[df['Provider Id'].isin(transplant_hospitals)]
df_avg_charge = transplant_hospitals_df

# %%
df_avg_charge = transplant_hospitals_df
provider_state_name = df_avg_charge[
    'Provider Name'].str.cat(df_avg_charge['Provider State'], sep=' - ').values
df_avg_charge = df_avg_charge.assign(Provider_Name_State=provider_state_name)
df_avg_charge = df_avg_charge.groupby(['Provider Id', 'Provider State', 'Provider_Name_State']).agg({acc : np.sum, drg_def : "count"})
df_avg_charge['Avg_ACC'] = df_avg_charge[acc] / df_avg_charge[drg_def]

# %% [markdown]
# #### 10 most expensive tertiary care centers in the United States

# %%
df_avg_charge.sort_values('Avg_ACC', ascending=False)[:10]
# Out:
#                                                                                Average Covered Charges  \
# Provider Id Provider State Provider_Name_State
# 50441       CA             STANFORD HOSPITAL - CA                                         5.341782e+07
# 50696       CA             KECK HOSPITAL OF USC - CA                                      1.895002e+07
# 50625       CA             CEDARS-SINAI MEDICAL CENTER - CA                               5.966825e+07
# 50454       CA             UCSF MEDICAL CENTER - CA                                       3.720521e+07
# 390027      PA             TEMPLE UNIVERSITY HOSPITAL - PA                                1.966517e+07
# 390290      PA             HAHNEMANN UNIVERSITY HOSPITAL - PA                             1.666164e+07
# 50599       CA             UNIVERSITY OF CALIFORNIA DAVIS MEDICAL CENTER - CA             3.184210e+07
# 330234      NY             WESTCHESTER MEDICAL CENTER - NY                                1.809981e+07
# 390111      PA             HOSPITAL OF UNIV OF PENNSYLVANIA - PA                          3.439441e+07
# 390164      PA             UPMC PRESBYTERIAN SHADYSIDE - PA                               4.224227e+07
#
#                                                                                DRG Definition  \
# Provider Id Provider State Provider_Name_State
# 50441       CA             STANFORD HOSPITAL - CA                                         226
# 50696       CA             KECK HOSPITAL OF USC - CA                                       93
# 50625       CA             CEDARS-SINAI MEDICAL CENTER - CA                               300
# 50454       CA             UCSF MEDICAL CENTER - CA                                       204
# 390027      PA             TEMPLE UNIVERSITY HOSPITAL - PA                                112
# 390290      PA             HAHNEMANN UNIVERSITY HOSPITAL - PA                              96
# 50599       CA             UNIVERSITY OF CALIFORNIA DAVIS MEDICAL CENTER - CA             185
# 330234      NY             WESTCHESTER MEDICAL CENTER - NY                                111
# 390111      PA             HOSPITAL OF UNIV OF PENNSYLVANIA - PA                          230
# 390164      PA             UPMC PRESBYTERIAN SHADYSIDE - PA                               285
#
#                                                                                      Avg_ACC
# Provider Id Provider State Provider_Name_State
# 50441       CA             STANFORD HOSPITAL - CA                              236362.056726
# 50696       CA             KECK HOSPITAL OF USC - CA                           203763.631757
# 50625       CA             CEDARS-SINAI MEDICAL CENTER - CA                    198894.182469
# 50454       CA             UCSF MEDICAL CENTER - CA                            182378.486738
# 390027      PA             TEMPLE UNIVERSITY HOSPITAL - PA                     175581.880087
# 390290      PA             HAHNEMANN UNIVERSITY HOSPITAL - PA                  173558.746838
# 50599       CA             UNIVERSITY OF CALIFORNIA DAVIS MEDICAL CENTER - CA  172119.474454
# 330234      NY             WESTCHESTER MEDICAL CENTER - NY                     163061.357481
# 390111      PA             HOSPITAL OF UNIV OF PENNSYLVANIA - PA               149540.903329
# 390164      PA             UPMC PRESBYTERIAN SHADYSIDE - PA                    148218.487258

# %% [markdown]
# #### 10 least expensive tertiary care centers in the United States

# %%
df_avg_charge.sort_values('Avg_ACC', ascending=True)[:10]
# Out:
#                                                                              Average Covered Charges  \
# Provider Id Provider State Provider_Name_State
# 230059      MI             SAINT MARY'S HEALTH CARE - MI                                2.683196e+06
# 220171      MA             LAHEY HOSPITAL & MEDICAL CENTER, BURLINGTON - MA             5.381772e+06
# 350015      ND             SANFORD MEDICAL CENTER BISMARCK - ND                         2.578040e+06
# 330219      NY             ERIE COUNTY MEDICAL CENTER - NY                              1.933226e+06
# 220077      MA             BAYSTATE MEDICAL CENTER - MA                                 6.949951e+06
# 210009      MD             JOHNS HOPKINS HOSPITAL, THE - MD                             9.042139e+06
# 360016      OH             JEWISH HOSPITAL, LLC - OH                                    2.645302e+06
# 390067      PA             PINNACLE HEALTH HOSPITALS - PA                               6.086634e+06
# 220031      MA             BOSTON MEDICAL CENTER CORPORATION - MA                       5.080589e+06
# 230165      MI             ST JOHN HOSPITAL AND MEDICAL CENTER - MI                     6.496761e+06
#
#                                                                              DRG Definition  \
# Provider Id Provider State Provider_Name_State
# 230059      MI             SAINT MARY'S HEALTH CARE - MI                                105
# 220171      MA             LAHEY HOSPITAL & MEDICAL CENTER, BURLINGTON - MA             203
# 350015      ND             SANFORD MEDICAL CENTER BISMARCK - ND                          85
# 330219      NY             ERIE COUNTY MEDICAL CENTER - NY                               63
# 220077      MA             BAYSTATE MEDICAL CENTER - MA                                 220
# 210009      MD             JOHNS HOPKINS HOSPITAL, THE - MD                             280
# 360016      OH             JEWISH HOSPITAL, LLC - OH                                     79
# 390067      PA             PINNACLE HEALTH HOSPITALS - PA                               179
# 220031      MA             BOSTON MEDICAL CENTER CORPORATION - MA                       142
# 230165      MI             ST JOHN HOSPITAL AND MEDICAL CENTER - MI                     180
#
#                                                                                   Avg_ACC
# Provider Id Provider State Provider_Name_State
# 230059      MI             SAINT MARY'S HEALTH CARE - MI                     25554.247809
# 220171      MA             LAHEY HOSPITAL & MEDICAL CENTER, BURLINGTON - MA  26511.191084
# 350015      ND             SANFORD MEDICAL CENTER BISMARCK - ND              30329.886137
# 330219      NY             ERIE COUNTY MEDICAL CENTER - NY                   30686.133328
# 220077      MA             BAYSTATE MEDICAL CENTER - MA                      31590.686643
# 210009      MD             JOHNS HOPKINS HOSPITAL, THE - MD                  32293.352566
# 360016      OH             JEWISH HOSPITAL, LLC - OH                         33484.830219
# 390067      PA             PINNACLE HEALTH HOSPITALS - PA                    34003.539174
# 220031      MA             BOSTON MEDICAL CENTER CORPORATION - MA            35778.792293
# 230165      MI             ST JOHN HOSPITAL AND MEDICAL CENTER - MI          36093.115319

# %% [markdown]
# #### Some observations on the above.
#
# * California seems to have a density of the most expensive tertiary care centers in the country
# * interestingly, there is some overlap state-wise between the lists. Some of the most expensive and least expensive tertiary care centers in the country can be found in the same state.
#
# #### Implications
#
# One of the implications of this data is that it may be more cost effective to perform complex care at less expensive institutions.

# %% [markdown]
# ## Q5: Is there a statistically significant difference in the prices charged for treating pneumonia in California vs. New York?

# %% [markdown]
# To first try and answer this question, let us look at a histogram of the charge data in each area to gauge it's distribution.

# %%
cal = df[(df['Provider State'] == 'CA') & (df['DRG Definition'] == '195 - SIMPLE PNEUMONIA & PLEURISY W/O CC/MCC')]
ny = df[(df['Provider State'] == 'NY') & (df['DRG Definition'] == '195 - SIMPLE PNEUMONIA & PLEURISY W/O CC/MCC')]

# %%
bins = np.arange(0, 110000, 5000)
plt.hist(cal[acc], bins=bins, histtype='step', label="CA")
plt.hist(ny[acc], bins=bins, histtype='step', label="NY")
plt.axvline(cal[acc].mean(), color="blue", label="Avg ACC in CA", linestyle='dashed')
plt.axvline(ny[acc].mean(), color='orange', label="Avg ACC in NY", linestyle='dashed')
plt.xlabel("Average Charge for PNA")
plt.ylabel("Number of institutions")
plt.title("Histogram of Average Charge of PNA in CA vs. NY")
plt.legend()
plt.show()

# %% [markdown]
# ### We can test whether these distributions are normal by using QQ plots.

# %%
normal_ny = np.random.normal(0, 1, len(ny[acc]))
normal_cal = np.random.normal(0, 1, len(cal[acc]))
normal_ny.sort()
normal_cal.sort()

# %%
ny_vals = ny[acc].sort_values()
cal_vals = cal[acc].sort_values()

# %% [markdown]
# ??? Put these side

# %%
measurements = np.random.normal(loc = 20, scale = 5, size=100)  
# returns tuples
(osm, osr), (slope, intercept, r) = stats.probplot(ny_vals, dist="norm", plot=plt)
plt.title("QQ plot for New York Average Charges for PNA")
plt.show()

# %%
# you reject the assumption
stats.jarque_bera(ny_vals)
# Out:
# (7.9404191460179172, 0.018869478187419575)

# %%
(osm, osr), (slope, intercept, r) = stats.probplot(cal_vals, dist="norm", plot=plt)
plt.title("QQ plot for CA Average Charges for PNA")
plt.show()

print(r)
# Out:
# 0.968827645325

# %%
stats.jarque_bera(cal_vals)
# Out:
# (37.475627708557987, 7.2823381769282491e-09)

# %% [markdown]
# ### So NY seems more normally distributed than California, though neither sample is _that_ normal. The sample size for NY is 100 providers and 134 providers in CA.
#
# ### Chosing a statistical test to determine whether the mean values of the distribution are different.
#
# Given that the distributions of our samples are not normal, a Mann-Whitney U test is our test of choice.

# %%
# works by comparing the medians, not the means
# distribution is reasonably normal, which supports use of the T-test; finite variance
# mann whitney hugh test compares medians to medians / orders the values
# ttest makes asscumptions about how the data is distributed (parametric test => relies on the data coming from a particular distribution w/ particular parameters)
# non-parametric test => does not need specific parameters in the distributions it tests (e.g. median)
print(stats.mannwhitneyu(ny_vals, cal_vals))
print(stats.ttest_ind(ny_vals, cal_vals, equal_var=False))
# Out:
# MannwhitneyuResult(statistic=1647.0, pvalue=3.0100533344227426e-23)
# Ttest_indResult(statistic=-12.041679026237272, pvalue=4.8684688835686721e-26)

# %% [markdown]
# The p-value < 5% indicates that there was a less than 5% chance of getting these two distributions if, infact, the cost of a pneumonia hospitalization was the same in these two regions. We can therefore say that the prices in the regions are likely different.

# %% [markdown]
# ## Q6: Is there a relationship between the number of hospitals in a HRR and average charge they request for a DRG?

# %% [markdown]
# We can plot the average covered charge for a given DRG in an HRR and plot it against the number of providers within the HRR to get a sense of the relationship. We can perform a linear regression to assess for the significance of this relationship. Given that there are hundreds of DRG's, we will start by just looking at the relation between ACC and the number of providers in a HRR.

# %%
providers_per_hrr = df.groupby([hrr]).agg({acc : np.mean, 'Provider Id' : 'count'})
x = providers_per_hrr['Provider Id']
y = providers_per_hrr['Average Covered Charges']
m, b, r, p, e = stats.linregress(x, y)
line_x = np.array([x.min(), x.max()])
line_y = m * line_x + b
plt.plot(line_x, line_y, '--k')
plt.scatter(x=providers_per_hrr['Provider Id'], y=providers_per_hrr['Average Covered Charges'])
plt.title("Num Providers per HRR vs. Average Covered Charges")
plt.xlabel("Providers per HRR")
plt.ylabel("Average Covered Charges")
plt.text(3200, 160000, '$R^2={:.3f}$'.format(r*r))
plt.text(3200, 150000, '$p = {:.3f}$'.format(p))
plt.text(3200, 140000, '$m = {:.3f}$'.format(m))

plt.show()

# %% [markdown]
# There is an increase in the average covered charge made to medicare as the number of providers increases. This is interesting, as more competition (i.e. more providers per HRR) would make me suspect that the prices would go down as insurers and patients have more hospitals to choose from. However, it is also very likely in these areas with a high number of hospitals per HRR that there are a lot of people, which would result in increased demand for hospital services.
#
# Let's further investigate this by performing linear regressions comparing the number of providers per HRR to the Average Covered Charge per DRG.

# %%
providers_per_hrr_per_DRG = df.groupby(['DRG Definition', hrr]).agg({
    'Provider Id' : 'count', acc : np.mean}).reset_index()

DRG_list = providers_per_hrr_per_DRG['DRG Definition'].unique()

stat_summary = pd.DataFrame(columns=['num_provs_per_DRG_avg', 'HRR_count', 'HRR_min', \
                                     'HRR_max', 'min_cost', 'max_cost', "cost_range", 'avg_cost', 'm','p', 'r'])
for DRG in DRG_list:
    DRG_df = providers_per_hrr_per_DRG[providers_per_hrr_per_DRG['DRG Definition'] == DRG]
    num_provs_per_DRG_avg = DRG_df['Provider Id'].mean()
    cost_DRG_per_HRR_avg = DRG_df[acc].mean()
    HRR_count = DRG_df[hrr].count()
    max_cost = DRG_df[DRG_df[acc] == DRG_df[acc].max()][acc].values[0]
    min_cost = DRG_df[DRG_df[acc] == DRG_df[acc].min()][acc].values[0]
    cost_range = max_cost - min_cost
    HRR_min = DRG_df[DRG_df[acc] == DRG_df[acc].max()][hrr].values[0]
    HRR_max = DRG_df[DRG_df[acc] == DRG_df[acc].min()][hrr].values[0]
    m, b, r, p, e = stats.linregress(DRG_df['Provider Id'], DRG_df[acc])
    stat_summary.loc[DRG , :] = num_provs_per_DRG_avg, \
        HRR_count, HRR_min, HRR_max, min_cost, max_cost, cost_range, cost_DRG_per_HRR_avg, m, p, r

# %%
significant_and_pos = stat_summary[(stat_summary.p < .05) & (stat_summary.m > 0)]
significant_and_neg = stat_summary[(stat_summary.p < .05) & (stat_summary.m < 0)]
insignificant = stat_summary[stat_summary.p >= .05]

# %%
print(significant_and_pos.shape[0])
print(significant_and_neg.shape[0])
print(insignificant.shape[0])
# Out:
# 67
# 0
# 430

# %% [markdown]
# ### Observations
# Of the 564 unique DRG's, we were only able to perform linear regressions on 497 of them. Of those 497, 67 had a positive slope and were statistically significant. There were 0 DRG's that had a statistically significant negative relationship between number of providers per HRR and ACC (i.e. cheaper charges when there are more providers in a given area). The remaining 430 regressions were not statistically significant.
#
# This, like the above aggregate graph is intersting to me as it seems to vioalte some economics 101 assumptions - that increasing the supply of a good should result in lowered cost. However, as noted above, we are not accounting for the demand side of that equation, as areas that have more hospitals also, in all likelihood, have more patients to take care of. Below we will investigate this relationship further.

# %% [markdown]
# ## Q7: what about the relationship between population enrolled in medicare within an HRR and ACC for a DRG in a given HRR?

# %% [markdown]
# To account for this, we will merge in data from the Medicare Beneficiaries file imported above.

# %%
grouped_HRR_df = df.groupby(hrr).agg({"Total Discharges" : np.sum, "Provider Id" : "count", acc : np.mean}).reset_index()

enrollees = 'Medicare Beneficiaries Enrolled in FFS Part A'
bennies = pd.merge(grouped_HRR_df, HRR_names_and_beneficiaries, how='left', left_on=hrr, right_on='HRR Name')
missing_rows = np.where(pd.isnull(bennies))[0]
missing_rows = np.unique(missing_rows)
len(missing_rows) # there are 170 missing rows out of 57665
bennies = bennies.dropna()

y = bennies[acc]
x = bennies[enrollees]
m, b, r, p, e = stats.linregress(x, y)
x_line = np.array([x.min(), x.max()])
y_line = m * x_line + b
plt.scatter(x, y)
plt.plot(x_line, y_line, '--k')
plt.text(x.max() * .85, y.max()* .9, '$R^2={:.3f}$'.format(r*r))
plt.text(x.max() * .85, y.max() * .85, '$p = {:.3f}$'.format(p))
plt.text(x.max() * .85, y.max() * .80, '$m = {:.3f}$'.format(m))
plt.title("Population per HRR vs ACC")
plt.xlabel("Population per HRR")
plt.ylabel("ACC")
plt.show()

# %% [markdown]
# This graph shows that there is a statistically significant positive relationsihp between population per HRR and the average covered cost. This jives well with the above analysis that showed an increase in averaged covered cost as the number of providers per HRR increase.

# %% [markdown]
# ### Let's see how medicare population per HRR relates to ACC for each DRG.

# %%
# this gives the total discharges and num of unique providers
unique_providers = df.groupby(['DRG Definition', hrr]).agg({"Total Discharges" : np.sum,
                                                            "Provider Id" : 'count', 
                                                            acc : np.mean})

# resets the index
unique_providers_reset = unique_providers.reset_index()
filtered = unique_providers_reset

enrollees = 'Medicare Beneficiaries Enrolled in FFS Part A'
bennies = pd.merge(filtered, HRR_names_and_beneficiaries, how='left', left_on=hrr, right_on='HRR Name')
missing_rows = np.where(pd.isnull(bennies))[0]
missing_rows = np.unique(missing_rows)
len(missing_rows) # there are 170 missing rows out of 57665
bennies = bennies.dropna()

# %%
bennies
# Out:
#                                           DRG Definition  \
# 0      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 1      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 2      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 3      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 4      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 5      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 6      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 7      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 8      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 9      001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 10     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 11     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 12     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 13     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 14     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 15     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 16     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 17     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 18     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 19     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 20     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 21     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 22     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 23     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 24     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 25     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 26     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 27     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 28     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# 29     001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...
# ...                                                  ...
# 57635  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57636  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57637  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57638  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57639  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57640  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57641  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57642  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57643  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57644  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57645  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57646  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57647  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57648  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57649  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57650  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57651  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57652  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57653  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57654  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57655  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57656  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57657  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57658  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57659  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57660  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57661  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57662  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57663  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
# 57664  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...
#
#       Hospital Referral Region (HRR) Description  Total Discharges  \
# 0                                AL - Birmingham                13
# 1                                   AZ - Phoenix                20
# 2                               CA - Los Angeles                57
# 3                                CA - Sacramento                25
# 4                             CA - San Francisco                20
# 5                          CA - San Mateo County                23
# 6                                  CT - Hartford                17
# 7                                 CT - New Haven                12
# 8                                DC - Washington                31
# 9                               FL - Gainesville                16
# 10                             FL - Jacksonville                19
# 11                                  FL - Orlando                15
# 12                                    FL - Tampa                33
# 13                                  GA - Atlanta                37
# 14                              IL - Blue Island                43
# 15                                  IL - Chicago                51
# 16                             IL - Melrose Park                15
# 17                             IN - Indianapolis                34
# 18                                KY - Lexington                11
# 19                               KY - Louisville                16
# 20                              LA - New Orleans                15
# 21                                   MA - Boston                47
# 22                                MI - Ann Arbor                25
# 23                                  MI - Detroit                14
# 24                             MI - Grand Rapids                18
# 25                              MN - Minneapolis                30
# 26                                MN - Rochester                16
# 27                              MO - Kansas City                13
# 28                                MO - St. Louis                77
# 29                                NC - Charlotte                11
# ...                                          ...               ...
# 57635                               NE - Lincoln                20
# 57636                                NJ - Camden                42
# 57637                            NJ - Hackensack                11
# 57638                            NJ - Morristown                11
# 57639                                NJ - Newark                16
# 57640                             NJ - Ridgewood                11
# 57641                                 NY - Bronx                15
# 57642                      NY - East Long Island                24
# 57643                             NY - Manhattan                39
# 57644                                OH - Canton                11
# 57645                             OH - Cleveland                16
# 57646                              OH - Columbus                17
# 57647                              PA - Danville                11
# 57648                          PA - Philadelphia                28
# 57649                            PA - Pittsburgh                15
# 57650                               PA - Reading                16
# 57651                              SC - Florence                15
# 57652                            SC - Greenville                13
# 57653                           SC - Spartanburg                11
# 57654                               TN - Memphis                12
# 57655                               TX - Houston                28
# 57656                           TX - San Antonio                26
# 57657                                 TX - Tyler                12
# 57658                               WI - Madison                15
# 57659                             WI - Milwaukee                13
# 57660                            WV - Charleston                28
# 57661                            WV - Huntington                17
# 57662                            KY - Louisville                13
# 57663                           MO - Kansas City                13
# 57664                             NY - Manhattan                13
#
#        Provider Id  Average Covered Charges  HRR Code               HRR Name  \
# 0                1             1.172866e+06       1.0        AL - Birmingham
# 1                1             4.375313e+05      12.0           AZ - Phoenix
# 2                2             1.799698e+06      56.0       CA - Los Angeles
# 3                1             8.156741e+05      77.0        CA - Sacramento
# 4                1             1.556265e+06      81.0     CA - San Francisco
# 5                1             2.238699e+06      85.0  CA - San Mateo County
# 6                1             5.241018e+05     110.0          CT - Hartford
# 7                1             1.127301e+06     111.0         CT - New Haven
# 8                1             7.807814e+05     113.0        DC - Washington
# 9                1             5.909152e+05     120.0       FL - Gainesville
# 10               1             4.461910e+05     123.0      FL - Jacksonville
# 11               1             9.721275e+05     130.0           FL - Orlando
# 12               1             1.127967e+06     141.0             FL - Tampa
# 13               2             7.148593e+05     144.0           GA - Atlanta
# 14               1             8.996904e+05     155.0       IL - Blue Island
# 15               2             1.056580e+06     156.0           IL - Chicago
# 16               1             5.626910e+05     166.0      IL - Melrose Park
# 17               2             8.785995e+05     183.0      IN - Indianapolis
# 18               1             7.320039e+05     204.0         KY - Lexington
# 19               1             8.253034e+05     205.0        KY - Louisville
# 20               1             7.996654e+05     218.0       LA - New Orleans
# 21               2             9.063524e+05     227.0            MA - Boston
# 22               1             7.152598e+05     232.0         MI - Ann Arbor
# 23               1             5.994208e+05     234.0           MI - Detroit
# 24               1             4.847304e+05     236.0      MI - Grand Rapids
# 25               2             7.787012e+05     251.0       MN - Minneapolis
# 26               1             4.321826e+05     253.0         MN - Rochester
# 27               1             9.170079e+05     268.0       MO - Kansas City
# 28               1             6.783885e+05     273.0         MO - St. Louis
# 29               1             5.850855e+05     311.0         NC - Charlotte
# ...            ...                      ...       ...                    ...
# 57635            1             4.301655e+04     277.0           NE - Lincoln
# 57636            3             9.799059e+04     283.0            NJ - Camden
# 57637            1             7.996027e+04     284.0        NJ - Hackensack
# 57638            1             6.027736e+04     285.0        NJ - Morristown
# 57639            1             7.746688e+04     289.0            NJ - Newark
# 57640            1             5.334591e+04     292.0         NJ - Ridgewood
# 57641            1             8.823480e+04     297.0             NY - Bronx
# 57642            1             6.813558e+04     301.0  NY - East Long Island
# 57643            2             6.414504e+04     303.0         NY - Manhattan
# 57644            1             3.594155e+04     326.0            OH - Canton
# 57645            1             7.027906e+04     328.0         OH - Cleveland
# 57646            1             5.230641e+04     329.0          OH - Columbus
# 57647            1             7.919909e+04     350.0          PA - Danville
# 57648            2             8.437240e+04     356.0      PA - Philadelphia
# 57649            1             1.169221e+05     357.0        PA - Pittsburgh
# 57650            1             4.981625e+04     358.0           PA - Reading
# 57651            1             1.226987e+05     367.0          SC - Florence
# 57652            1             4.660285e+04     368.0        SC - Greenville
# 57653            1             4.251909e+04     369.0       SC - Spartanburg
# 57654            1             3.618008e+04     379.0           TN - Memphis
# 57655            1             7.791032e+04     397.0           TX - Houston
# 57656            2             5.912580e+04     412.0       TX - San Antonio
# 57657            1             8.931858e+04     416.0             TX - Tyler
# 57658            1             3.058027e+04     449.0           WI - Madison
# 57659            1             6.320408e+04     451.0         WI - Milwaukee
# 57660            2             4.104589e+04     443.0        WV - Charleston
# 57661            1             2.304435e+04     444.0        WV - Huntington
# 57662            1             2.433500e+04     205.0        KY - Louisville
# 57663            1             2.636138e+04     268.0       MO - Kansas City
# 57664            1             3.483262e+04     303.0         NY - Manhattan
#
#        Medicare Beneficiaries Enrolled in FFS Part A  \
# 0                                           332912.0
# 1                                           352817.0
# 2                                           682316.0
# 3                                           266669.0
# 4                                           142874.0
# 5                                            73567.0
# 6                                           201610.0
# 7                                           197733.0
# 8                                           356849.0
# 9                                            86518.0
# 10                                          212165.0
# 11                                          464600.0
# 12                                          127704.0
# 13                                          605010.0
# 14                                          120367.0
# 15                                          252040.0
# 16                                          162309.0
# 17                                          374550.0
# 18                                          225819.0
# 19                                          250083.0
# 20                                           55119.0
# 21                                          714325.0
# 22                                          168616.0
# 23                                          215255.0
# 24                                          110190.0
# 25                                          255950.0
# 26                                           47072.0
# 27                                          306685.0
# 28                                          438874.0
# 29                                          293229.0
# ...                                              ...
# 57635                                        95853.0
# 57636                                       459722.0
# 57637                                       168873.0
# 57638                                       147577.0
# 57639                                       163700.0
# 57640                                        58949.0
# 57641                                        87794.0
# 57642                                       546596.0
# 57643                                       460843.0
# 57644                                        68145.0
# 57645                                       248848.0
# 57646                                       319448.0
# 57647                                        68629.0
# 57648                                       490270.0
# 57649                                       265126.0
# 57650                                        77430.0
# 57651                                        62193.0
# 57652                                       126990.0
# 57653                                        53365.0
# 57654                                       241837.0
# 57655                                       543167.0
# 57656                                       284888.0
# 57657                                        87623.0
# 57658                                       140155.0
# 57659                                       300222.0
# 57660                                       142717.0
# 57661                                        60707.0
# 57662                                       250083.0
# 57663                                       306685.0
# 57664                                       460843.0
#
#        Medicare Beneficiaries Enrolled in FFS Part B
# 0                                           313260.0
# 1                                           322596.0
# 2                                           630783.0
# 3                                           248227.0
# 4                                           127905.0
# 5                                            63136.0
# 6                                           182089.0
# 7                                           175939.0
# 8                                           310001.0
# 9                                            80181.0
# 10                                          197638.0
# 11                                          430595.0
# 12                                          115019.0
# 13                                          558617.0
# 14                                          110888.0
# 15                                          231251.0
# 16                                          146648.0
# 17                                          349143.0
# 18                                          215639.0
# 19                                          234942.0
# 20                                           47624.0
# 21                                          637322.0
# 22                                          155983.0
# 23                                          201628.0
# 24                                          101914.0
# 25                                          225209.0
# 26                                           43476.0
# 27                                          280657.0
# 28                                          403465.0
# 29                                          274959.0
# ...                                              ...
# 57635                                        89200.0
# 57636                                       423697.0
# 57637                                       153811.0
# 57638                                       133526.0
# 57639                                       147926.0
# 57640                                        53327.0
# 57641                                        75976.0
# 57642                                       486271.0
# 57643                                       400535.0
# 57644                                        62145.0
# 57645                                       224244.0
# 57646                                       293511.0
# 57647                                        62715.0
# 57648                                       429183.0
# 57649                                       226904.0
# 57650                                        70497.0
# 57651                                        60067.0
# 57652                                       119667.0
# 57653                                        50526.0
# 57654                                       222940.0
# 57655                                       479843.0
# 57656                                       260681.0
# 57657                                        82829.0
# 57658                                       128132.0
# 57659                                       276994.0
# 57660                                       134439.0
# 57661                                        57554.0
# 57662                                       234942.0
# 57663                                       280657.0
# 57664                                       400535.0
#
# [57495 rows x 9 columns]

# %%
population_HRR_regression_df = pd.DataFrame(columns=["avg_acc", "num_HRRs", "avg_provs_per_HRR", "m", "p", "r"])
for DRG in bennies['DRG Definition'].unique():
    dx = bennies[bennies['DRG Definition']==DRG]
    x = dx[enrollees]
    y = dx[acc]
    avg_acc = dx[acc].mean()
    avg_provs_per_HRR = dx['Provider Id'].mean()
    num_HRRs = dx.shape[0]
    m, b, r, p, e = stats.linregress(x, y)
    population_HRR_regression_df.loc[DRG] = avg_acc, num_HRRs, avg_provs_per_HRR, m, p, r

# %%
significant_and_pos = population_HRR_regression_df[(population_HRR_regression_df.p < .05) & (population_HRR_regression_df.m > 0)]
significant_and_neg = population_HRR_regression_df[(population_HRR_regression_df.p < .05) & (population_HRR_regression_df.m < 0)]
insignificant = population_HRR_regression_df[population_HRR_regression_df.p >= .05]

# %%
print(insignificant.shape[0])
print(significant_and_neg.shape[0])
print(significant_and_pos.shape[0])
# Out:
# 296
# 0
# 201

# %% [markdown]
# ### Observations
# Of the 564 unique DRG's, we were again only able to perform linear regressions on 497 of them. Of those 497, 201 had a positive slope and were statistically significant. There were 0 DRG's that had a statistically significant negative relationship between number of providers per HRR and ACC (i.e. cheaper charges when there are more providers in a given area). The remaining 296 regressions were not statistically significant.
#
# Overall, this suggests that an increase in the size of the medicare population in an HRR is associated with an increased charge for a given DRG (or at least 201 of them). This makes sense to me as medicare reimburses significantly less for a given DRG compared to private insurers. The more medicare patients you have, the more you need to charge patients off of medicare to recoup the losses you sustain from medicare's poor reimbursement.
#
# A limitation to the above is that the medicare population is only a fraction of the whole popualtion. It would be great to see how the cost varied base on the percentage of the population that receives medicare within an HRR (or the popuation as a whole within an HRR), yet I don't have a good dataset on that right now. Something to keep in mind for the future!

# %% [markdown]
# ## Q8: Do teaching hospitals charge more for a given diagnosis than non-teaching hospitals?

# %% [markdown]
# This is common belief in the medical community. Intuitively, one would think this to be the case for several reasons. Teaching hospitals take on the burden of teaching medical students in residents, which takes time and effort that is reflected in the cost. Additionally, if trainees are taking care of patients, perhaps there are more mistakes make, more unnecessary medical imaging and labs ordered, more malpractice insurance to buy. Furthermore, academic institutions are usually research powerhouses that take care of more complex patients (e.g. those that require organ transplants, or those referred from secondary care centers).
#
# Let's see if, indeed, teaching hospitals do charge more for non-teaching hospitals. To simplify this analysis, we can assess this within the HRR's around Manhattan. Doing so will hopefully control for regional varianace.

# %%
# ??? this filter is not working well....how to make it better?
# e.g. michican and mayo clinic Florida. What's the best way to double check
teaching_names = teaching_hospitals['Hospital Name'].str.lower()

# bunch of attempts to ensure we find matches between the df's
df['teaching_hospital'] = df['Provider Name'].str.upper().isin(
    teaching_names.str.upper()) | df['Provider Street Address'].isin(
    teaching_hospitals['Street Address'].str.upper()) | df['Provider Name'].isin(
    teaching_hospitals['PECOS Legal Business Name'].str.upper())

# %%
# reordering columns
df.columns
col_ls = list(df.columns)
th = col_ls.pop()
col_ls.insert(3, th)
df = df[col_ls]

# %% [markdown]
# ### Comparing non-teaching vs. teaching Hospitals - is there a difference in price?

# %% [markdown]
# We can do this with a histogram. Below is a histogram of ACC's for teaching hospitals (ths) vs. non-teaching hospitals (nths). The range is max-range is truncated to emphasize the difference in ACC's.

# %%
ths = df[df.teaching_hospital == True]
nths = df[df.teaching_hospital == False]
n1, bins1, patches1 = plt.hist(ths[acc], normed=True, range=(ths[acc].min(), ths[acc].max()/9), histtype='step', label='ths ACC')
n2, bins2, patches2 = plt.hist(nths[acc], normed=True, range=(nths[acc].min(), nths[acc].max()/9), histtype='step', label='nths ACC')
ths_avg_acc = ths[acc].mean()
nths_avg_acc = nths[acc].mean()
plt.axvline(ths_avg_acc, color='blue', label = 'ths avg ACC')
plt.axvline(nths_avg_acc, color='orange', label="nths avg ACC")
plt.legend()
plt.title("ACC of Teaching vs. Non-teaching Hospitals")
plt.show()

# %%
# statistical test
stats.ttest_ind(ths[acc], nths[acc])
# Out:
# Ttest_indResult(statistic=36.966112978338749, pvalue=3.9896282006200123e-298)

# %% [markdown]
# ### Interpretation:
#
# Two-sided t-test was significant. T-statistic = difference between the sample standard errors. This implies the the average ACC of teaching hospitals is different from the average ACC of non teaching hospitals.

# %%
th_stats_df = pd.DataFrame(columns=['avg_acc_th', 'avg_acc_nth', 'num_th', 'num_nth', 'std_th', 
                                   'std_nth', 't', 'p'])
for DRG in df['DRG Definition'].unique():
    th_DRG = ths[ths['DRG Definition'] == DRG]
    nth_DRG = nths[nths['DRG Definition'] == DRG]
    
    avg_acc_th = th_DRG[acc].mean()
    avg_acc_nth = nth_DRG[acc].mean()
    num_th = th_DRG.shape[0]
    num_nth = nth_DRG.shape[0]
    std_th = th_DRG[acc].std()
    std_nth = nth_DRG[acc].std()
    
    t, p = stats.ttest_ind(th_DRG[acc], nth_DRG[acc])
    
    th_stats_df.loc[DRG, :] = avg_acc_th, avg_acc_nth, num_th, num_nth, std_th, std_nth, t, p
    
print("Gross results:", th_stats_df.shape)
th_stats_df = th_stats_df.dropna()
print("Removing nan values (e.g. only teaching hospitals do certain DRGs):", th_stats_df.shape[0])
th_sig_and_more = th_stats_df[(th_stats_df.avg_acc_th > th_stats_df.avg_acc_nth) & (th_stats_df.p < .05)]
print("ACC of TH > than NTH (significant):", th_sig_and_more.shape[0])
th_sig_and_less = th_stats_df[(th_stats_df.avg_acc_th < th_stats_df.avg_acc_nth) & (th_stats_df.p < .05)]
print("ACC of TH < than NTH (significant):",th_sig_and_less.shape[0])
th_insignificant = th_stats_df[(th_stats_df.p >= .05)]
print("comparison insignificant:",th_insignificant.shape[0])
# Out:
# Gross results: (459, 8)
# Removing nan values (e.g. only teaching hospitals do certain DRGs): 459
# ACC of TH > than NTH (significant): 106
# ACC of TH < than NTH (significant): 1
# comparison insignificant: 352

# %%
plt.figure(figsize=(10,10))
plt.scatter(th_insignificant.avg_acc_nth, th_insignificant.avg_acc_th, alpha=.5)
plt.scatter(th_sig_and_more.avg_acc_nth, th_sig_and_more.avg_acc_th, c='g')
plt.scatter(th_sig_and_less.avg_acc_nth, th_sig_and_less.avg_acc_th, c='r')
x_line = [-0, 1000000]
y_line = x_line
plt.plot(x_line, y_line, '--k')
plt.title('Teaching vs. Non-Teaching Hospitals Average Cost per DRG')
plt.xlabel('Cost of a given DRG in a Non-Teaching Hospital')
plt.ylabel('Cost of a given DRG in a Teaching Hospital')
plt.show()

# %% [markdown]
# ### Insurance analysis
#
# A significant proportion of the US population relies on private insurance rather than medicare. Private insurers negotiate with individual hospitals to establish a master charge list. The competitiveness of a given region's insurance market and the number of hospital providers in each region determine each provider and insurer's relative bargaining power in establishing prices. [This](http://kff.org/other/state-indicator/large-group-insurance-market-competition/?currentTimeframe=0 "Title") dataset has some excellent private insurance market geared that will enable us to assess the relationship between the competitiveness of a state's private insurance market and the ACC a provider charges.
#
# Note: "The *Herfindahl-Hirschman Index (HHI)* is a measure of how evenly market share is distributed across insurers in the market. HHI values range from 0 to 10,000, with an HHI closer to zero indicating a more competitive market and closer to 10,000 indicating a less competitive market. An HHI index below 1,000 generally indicates a highly competitive market; an HHI between 1,000 and 1,500 indicates an unconcentrated market; a score between 1,500 and 2,500 indicates moderate concentration; and a value above 2,500 indicates a highly concentrated (uncompetitive) market."

# %%
insurance_df = pd.read_csv("Private_insurers_raw_data.csv")

us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
    "District of Columbia" : "DC"
}

insurance_df.loc[:, 'location'] = insurance_df.location.map(us_state_abbrev)

insurance_merge = pd.merge(df, insurance_df, how='left', left_on="Provider State", right_on="location")

# %%
# Not the most useful graph; better way to graph discrete values?

accs = insurance_merge[acc]
HHI = insurance_merge.HHI
m, b, r, p, e = stats.linregress(HHI, accs)
x_line = np.array([HHI.min(), HHI.max()])
y_line = m * x_line + b

plt.figure(figsize=(15, 10))
plt.text(8000, 2000000, "$R^2={:.3f}$".format(r*r))
plt.text(8000, 1900000, "$p={:.3f}$".format(p))
plt.text(8000, 1800000, "$m={:.3f}$".format(m))
plt.plot(x_line, y_line, 'k--')
plt.scatter(HHI, accs)
plt.title("Plot of Average Covered Charges vs. HHI")
plt.xlabel("HHI")
plt.ylabel("ACC")
plt.show()

# %%
accs = insurance_merge[acc]
num_with_more_than_five = insurance_merge.num_with_more_than_five
m, b, r, p, e = stats.linregress(num_with_more_than_five, accs)
x_line = np.array([num_with_more_than_five.min(), num_with_more_than_five.max()])
y_line = m * x_line + b

plt.figure(figsize=(15, 10))
plt.text(6.7, 2000000, "$R^2={:.3f}$".format(r*r))
plt.text(6.7, 1900000, "$p={:.3f}$".format(p))
plt.text(6.7, 1800000, "$m={:.3f}$".format(m))
plt.plot(x_line, y_line, 'k--')
plt.scatter(num_with_more_than_five, accs)
plt.title("Plot of Average Covered Charges vs. number of insurance providers in a state that have more than 5% market share")
plt.xlabel("num_with_more_than_five")
plt.ylabel("ACC")
plt.show()

# %%
std = df.groupby('Provider State')[acc].transform(np.std)
df = df.assign(std_state_cost = std)

# %%
state_cost_df = df.groupby(['DRG Definition', 'Provider State']).agg({'Provider Id' : 'count', 
                                                  acc : np.mean, "std_state_cost" : np.mean}).reset_index()
state_cost_df= pd.merge(state_cost_df, insurance_df, how='left', left_on="Provider State", right_on="location")

# %%
HHI_by_DRG_regression = pd.DataFrame(columns=['avg_cost', 'num_providers', 'max_cost', 'min_cost', "cost_dif", 'std_costs', "r", "p", "m"])

for DRG in state_cost_df['DRG Definition'].unique():
    DRG_df = state_cost_df[state_cost_df['DRG Definition'] == DRG]
    ACCs = DRG_df[acc]
    HHIs = DRG_df.HHI
    
    m, b, r, p, e = stats.linregress(HHIs, ACCs)
    avg_cost = ACCs.mean()
    max_cost = ACCs.max()
    min_cost = ACCs.min()
    std_costs = ACCs.std()
    num_providers = DRG_df['Provider Id'].sum()
    cost_dif = m * (HHIs.max() - HHIs.min())
    
    HHI_by_DRG_regression.loc[DRG, :] = avg_cost, num_providers, max_cost, min_cost, cost_dif, std_costs, r, p, m

# %%
HHI_by_DRG_regression = HHI_by_DRG_regression.assign(m_floor=HHI_by_DRG_regression.m.map(np.floor))

# %%
rank = np.arange(HHI_by_DRG_regression.shape[0])
temp_sort = HHI_by_DRG_regression.sort_values('avg_cost')
temp_sort = temp_sort.assign(cost_rank=rank)
temp_sort.sort_index(inplace=True)
HHI_by_DRG_regression = temp_sort

# %%
sig_HHI_by_DRG = HHI_by_DRG_regression[HHI_by_DRG_regression.p < .05]
insig_HHI_by_DRG = HHI_by_DRG_regression[HHI_by_DRG_regression.p >= .05]

# %%
plt.hist(sig_HHI_by_DRG.m_floor)
plt.title("plot of the significant floored m values from the regression")
plt.show()

# %%
plt.hist(insig_HHI_by_DRG.m_floor)
plt.title("plot of the insignificant floored m values from the regression")
plt.show()

# %%
# some of the characteristics of the significant regressions...
sig_HHI_by_DRG.sort_values('p', ascending=True)
# Out:
#                                                    avg_cost num_providers  \
# 742 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ...  50035.5           109
# 091 - OTHER DISORDERS OF NERVOUS SYSTEM W MCC       44076.9           319
# 743 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ...  30932.5           260
# 982 - EXTENSIVE O.R. PROCEDURE UNRELATED TO PRI...  76515.1           433
# 620 - O.R. PROCEDURES FOR OBESITY W CC              51206.5           115
# 406 - PANCREAS, LIVER & SHUNT PROCEDURES W CC       84760.7           133
# 375 - DIGESTIVE MALIGNANCY W CC                     34444.8           395
# 240 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP...  67404.7           169
# 086 - TRAUMATIC STUPOR & COMA, COMA <1 HR W CC        32110           534
# 857 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION...  57572.9           172
# 494 - LOWER EXTREM & HUMER PROC EXCEPT HIP,FOOT...    42635           519
# 025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...   116818           512
# 438 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W...  47452.5           355
# 580 - OTHER SKIN, SUBCUT TISS & BREAST PROC W CC    47287.8           103
# 125 - OTHER DISORDERS OF THE EYE W/O MCC            22168.4            21
# 027 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...  67764.5           271
# 196 - INTERSTITIAL LUNG DISEASE W MCC               47626.3            95
# 073 - CRANIAL & PERIPHERAL NERVE DISORDERS W MCC    37242.9           148
# 054 - NERVOUS SYSTEM NEOPLASMS W MCC                39829.4           311
# 336 - PERITONEAL ADHESIOLYSIS W CC                  62585.8           291
# 239 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP...   119522           193
# 472 - CERVICAL SPINAL FUSION W CC                   76272.4           385
# 038 - EXTRACRANIAL PROCEDURES W CC                    44413           375
# 205 - OTHER RESPIRATORY SYSTEM DIAGNOSES W MCC        49083            87
# 463 - WND DEBRID & SKN GRFT EXC HAND, FOR MUSCU...   160294            55
# 907 - OTHER O.R. PROCEDURES FOR INJURIES W MCC       110010           199
# 435 - MALIGNANCY OF HEPATOBILIARY SYSTEM OR PAN...  50162.5           342
# 175 - PULMONARY EMBOLISM W MCC                      38723.3           580
# 026 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...  87345.9           230
# 856 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION...   132444           108
# ...                                                     ...           ...
# 023 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS...   157008           181
# 003 - ECMO OR TRACH W MV 96+ HRS OR PDX EXC FAC...   453564           454
# 571 - SKIN DEBRIDEMENT W CC                         35372.1            17
# 041 - PERIPH/CRANIAL NERVE & OTHER NERV SYST PR...  67097.1            77
# 167 - OTHER RESP SYSTEM O.R. PROCEDURES W CC        51898.3           326
# 439 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W CC  25909.6           956
# 947 - SIGNS & SYMPTOMS W MCC                        35650.2           286
# 024 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS...   111557            30
# 809 - MAJOR HEMATOL/IMMUN DIAG EXC SICKLE CELL ...  33566.8           485
# 032 - VENTRICULAR SHUNT PROCEDURES W CC             58033.4            31
# 657 - KIDNEY & URETER PROCEDURES FOR NEOPLASM W CC  59266.8           180
# 155 - OTHER EAR, NOSE, MOUTH & THROAT DIAGNOSES...  26499.7            21
# 956 - LIMB REATTACHMENT, HIP & FEMUR PROC FOR M...   147752            61
# 225 - CARDIAC DEFIB IMPLANT W CARDIAC CATH W/O ...   177403            10
# 515 - OTHER MUSCULOSKELET SYS & CONN TISS O.R. ...  88612.1            26
# 379 - G.I. HEMORRHAGE W/O CC/MCC                      18119          1004
# 556 - SIGNS & SYMPTOMS OF MUSCULOSKELETAL SYSTE...  22971.8           382
# 221 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR...   128913           129
# 250 - PERC CARDIOVASC PROC W/O CORONARY ARTERY ...   100842           280
# 226 - CARDIAC DEFIBRILLATOR IMPLANT W/O CARDIAC...   196093            77
# 415 - CHOLECYSTECTOMY EXCEPT BY LAPAROSCOPE W/O...    46351            20
# 433 - CIRRHOSIS & ALCOHOLIC HEPATITIS W CC          28661.2            96
# 357 - OTHER DIGESTIVE SYSTEM O.R. PROCEDURES W CC   63352.7            96
# 217 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR...   166068           129
# 229 - OTHER CARDIOTHORACIC PROCEDURES W CC           138051            26
# 867 - OTHER INFECTIOUS & PARASITIC DISEASES DIA...  79881.7            46
# 552 - MEDICAL BACK PROBLEMS W/O MCC                 23281.4          1503
# 432 - CIRRHOSIS & ALCOHOLIC HEPATITIS W MCC         47410.7           298
# 313 - CHEST PAIN                                    18687.3          1719
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...  23638.2          1620
#
#                                                       max_cost min_cost  \
# 742 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ...      100393    16055
# 091 - OTHER DISORDERS OF NERVOUS SYSTEM W MCC          84580.8    22024
# 743 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ...     56789.8  13695.7
# 982 - EXTENSIVE O.R. PROCEDURE UNRELATED TO PRI...      141376  29454.1
# 620 - O.R. PROCEDURES FOR OBESITY W CC                  109666  16910.3
# 406 - PANCREAS, LIVER & SHUNT PROCEDURES W CC           176301  34623.4
# 375 - DIGESTIVE MALIGNANCY W CC                        65245.3  14712.6
# 240 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP...      169549  28841.7
# 086 - TRAUMATIC STUPOR & COMA, COMA <1 HR W CC         72761.3  10748.4
# 857 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION...      132560  21816.5
# 494 - LOWER EXTREM & HUMER PROC EXCEPT HIP,FOOT...     85627.8  19355.3
# 025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...      264822    39696
# 438 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W...     89034.1  16106.4
# 580 - OTHER SKIN, SUBCUT TISS & BREAST PROC W CC        110340  16213.7
# 125 - OTHER DISORDERS OF THE EYE W/O MCC               38113.3  10968.6
# 027 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...      129813  35069.9
# 196 - INTERSTITIAL LUNG DISEASE W MCC                   114021  20819.1
# 073 - CRANIAL & PERIPHERAL NERVE DISORDERS W MCC       66994.2  11887.5
# 054 - NERVOUS SYSTEM NEOPLASMS W MCC                   89158.2  17403.1
# 336 - PERITONEAL ADHESIOLYSIS W CC                      122704    24700
# 239 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP...      321120  30588.9
# 472 - CERVICAL SPINAL FUSION W CC                       137014  29965.2
# 038 - EXTRACRANIAL PROCEDURES W CC                     92174.8  12209.7
# 205 - OTHER RESPIRATORY SYSTEM DIAGNOSES W MCC          105151  20776.9
# 463 - WND DEBRID & SKN GRFT EXC HAND, FOR MUSCU...      398074  72791.6
# 907 - OTHER O.R. PROCEDURES FOR INJURIES W MCC          215496  54944.1
# 435 - MALIGNANCY OF HEPATOBILIARY SYSTEM OR PAN...     93453.6    19547
# 175 - PULMONARY EMBOLISM W MCC                         83995.3  16894.2
# 026 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...      170317  39611.2
# 856 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION...      290379  49188.4
# ...                                                        ...      ...
# 023 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS...      405645    67433
# 003 - ECMO OR TRACH W MV 96+ HRS OR PDX EXC FAC...  1.0182e+06   173550
# 571 - SKIN DEBRIDEMENT W CC                              57595  11104.9
# 041 - PERIPH/CRANIAL NERVE & OTHER NERV SYST PR...      137496  27534.5
# 167 - OTHER RESP SYSTEM O.R. PROCEDURES W CC            103938  18717.3
# 439 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W CC     48489.7  8495.57
# 947 - SIGNS & SYMPTOMS W MCC                           86267.3  13964.5
# 024 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS...      195981  41023.9
# 809 - MAJOR HEMATOL/IMMUN DIAG EXC SICKLE CELL ...     68768.8  12621.4
# 032 - VENTRICULAR SHUNT PROCEDURES W CC                 115135    19791
# 657 - KIDNEY & URETER PROCEDURES FOR NEOPLASM W CC      146352  19530.4
# 155 - OTHER EAR, NOSE, MOUTH & THROAT DIAGNOSES...     40806.6  8475.73
# 956 - LIMB REATTACHMENT, HIP & FEMUR PROC FOR M...      350497  35377.5
# 225 - CARDIAC DEFIB IMPLANT W CARDIAC CATH W/O ...      270953    69773
# 515 - OTHER MUSCULOSKELET SYS & CONN TISS O.R. ...      193484  24097.1
# 379 - G.I. HEMORRHAGE W/O CC/MCC                       38460.9  7219.81
# 556 - SIGNS & SYMPTOMS OF MUSCULOSKELETAL SYSTE...     47900.8  8100.13
# 221 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR...      245393    56742
# 250 - PERC CARDIOVASC PROC W/O CORONARY ARTERY ...      211915  32045.4
# 226 - CARDIAC DEFIBRILLATOR IMPLANT W/O CARDIAC...      389155    59163
# 415 - CHOLECYSTECTOMY EXCEPT BY LAPAROSCOPE W/O...     96922.6    14175
# 433 - CIRRHOSIS & ALCOHOLIC HEPATITIS W CC             68527.4  12241.4
# 357 - OTHER DIGESTIVE SYSTEM O.R. PROCEDURES W CC       150605    29411
# 217 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR...      347984  75057.3
# 229 - OTHER CARDIOTHORACIC PROCEDURES W CC              245708  52159.1
# 867 - OTHER INFECTIOUS & PARASITIC DISEASES DIA...      195880  31240.5
# 552 - MEDICAL BACK PROBLEMS W/O MCC                    50269.6  8918.65
# 432 - CIRRHOSIS & ALCOHOLIC HEPATITIS W MCC            97039.8    26908
# 313 - CHEST PAIN                                       38919.8  6818.55
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...     50891.5  8423.93
#
#                                                    cost_dif std_costs  \
# 742 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ... -41216.3     18408
# 091 - OTHER DISORDERS OF NERVOUS SYSTEM W MCC      -29524.3     15169
# 743 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ... -20701.7   10984.1
# 982 - EXTENSIVE O.R. PROCEDURE UNRELATED TO PRI... -38924.3   21515.2
# 620 - O.R. PROCEDURES FOR OBESITY W CC             -33308.2   17555.7
# 406 - PANCREAS, LIVER & SHUNT PROCEDURES W CC      -49244.4     26552
# 375 - DIGESTIVE MALIGNANCY W CC                    -18850.9   10348.7
# 240 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP... -56542.8   29703.3
# 086 - TRAUMATIC STUPOR & COMA, COMA <1 HR W CC     -18367.1   10659.9
# 857 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION... -41328.3   22970.1
# 494 - LOWER EXTREM & HUMER PROC EXCEPT HIP,FOOT... -20913.1   12219.4
# 025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR... -66830.3   39523.7
# 438 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W... -23684.9   13933.1
# 580 - OTHER SKIN, SUBCUT TISS & BREAST PROC W CC   -38039.7   21026.6
# 125 - OTHER DISORDERS OF THE EYE W/O MCC             -25317   9839.17
# 027 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR... -34024.4   20441.5
# 196 - INTERSTITIAL LUNG DISEASE W MCC              -41096.7   21362.5
# 073 - CRANIAL & PERIPHERAL NERVE DISORDERS W MCC   -25774.4     13499
# 054 - NERVOUS SYSTEM NEOPLASMS W MCC               -24610.7   14602.7
# 336 - PERITONEAL ADHESIOLYSIS W CC                 -31067.8   18513.9
# 239 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP...  -103561   58203.4
# 472 - CERVICAL SPINAL FUSION W CC                  -37865.9   24055.4
# 038 - EXTRACRANIAL PROCEDURES W CC                 -24352.3   15719.2
# 205 - OTHER RESPIRATORY SYSTEM DIAGNOSES W MCC     -42960.4   22766.2
# 463 - WND DEBRID & SKN GRFT EXC HAND, FOR MUSCU...  -144496   85728.1
# 907 - OTHER O.R. PROCEDURES FOR INJURIES W MCC     -55887.5     34877
# 435 - MALIGNANCY OF HEPATOBILIARY SYSTEM OR PAN... -25845.3   16621.1
# 175 - PULMONARY EMBOLISM W MCC                     -20949.1   13625.5
# 026 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR... -42557.9   26842.4
# 856 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION... -84192.3     49879
# ...                                                     ...       ...
# 023 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS... -90861.5   66811.7
# 003 - ECMO OR TRACH W MV 96+ HRS OR PDX EXC FAC...  -194498    150604
# 571 - SKIN DEBRIDEMENT W CC                        -24315.9   13777.6
# 041 - PERIPH/CRANIAL NERVE & OTHER NERV SYST PR... -40569.3   27475.2
# 167 - OTHER RESP SYSTEM O.R. PROCEDURES W CC       -20942.8   15742.7
# 439 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W CC -10717.5   8301.46
# 947 - SIGNS & SYMPTOMS W MCC                         -19603   14227.2
# 024 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS... -65104.1   34635.5
# 809 - MAJOR HEMATOL/IMMUN DIAG EXC SICKLE CELL ... -14231.3   11100.5
# 032 - VENTRICULAR SHUNT PROCEDURES W CC            -38190.8   23899.3
# 657 - KIDNEY & URETER PROCEDURES FOR NEOPLASM W CC -28671.7   22910.2
# 155 - OTHER EAR, NOSE, MOUTH & THROAT DIAGNOSES... -18630.6   9826.94
# 956 - LIMB REATTACHMENT, HIP & FEMUR PROC FOR M...  -111083   68671.7
# 225 - CARDIAC DEFIB IMPLANT W CARDIAC CATH W/O ...  -129889     63479
# 515 - OTHER MUSCULOSKELET SYS & CONN TISS O.R. ... -83642.7   45772.2
# 379 - G.I. HEMORRHAGE W/O CC/MCC                   -7967.55    6354.5
# 556 - SIGNS & SYMPTOMS OF MUSCULOSKELETAL SYSTE... -10366.5   8127.17
# 221 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR... -50127.9   39605.5
# 250 - PERC CARDIOVASC PROC W/O CORONARY ARTERY ... -44192.8   35214.4
# 226 - CARDIAC DEFIBRILLATOR IMPLANT W/O CARDIAC... -96406.8   62997.5
# 415 - CHOLECYSTECTOMY EXCEPT BY LAPAROSCOPE W/O... -40895.5   22172.6
# 433 - CIRRHOSIS & ALCOHOLIC HEPATITIS W CC         -20781.1   13811.9
# 357 - OTHER DIGESTIVE SYSTEM O.R. PROCEDURES W CC  -33821.5   24070.6
# 217 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR... -75617.6   56468.4
# 229 - OTHER CARDIOTHORACIC PROCEDURES W CC           -97987   53981.2
# 867 - OTHER INFECTIOUS & PARASITIC DISEASES DIA... -59886.9   38811.4
# 552 - MEDICAL BACK PROBLEMS W/O MCC                 -8859.5   7464.79
# 432 - CIRRHOSIS & ALCOHOLIC HEPATITIS W MCC        -19805.7   15403.2
# 313 - CHEST PAIN                                   -7514.54   6379.11
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR... -9728.94   8263.57
#
#                                                            r            p  \
# 742 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ... -0.537344  0.000419766
# 091 - OTHER DISORDERS OF NERVOUS SYSTEM W MCC      -0.462814   0.00155976
# 743 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ... -0.444426   0.00222448
# 982 - EXTENSIVE O.R. PROCEDURE UNRELATED TO PRI... -0.421249   0.00319069
# 620 - O.R. PROCEDURES FOR OBESITY W CC             -0.459776    0.0032323
# 406 - PANCREAS, LIVER & SHUNT PROCEDURES W CC      -0.443874   0.00323454
# 375 - DIGESTIVE MALIGNANCY W CC                     -0.43135   0.00346272
# 240 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP... -0.468237   0.00347038
# 086 - TRAUMATIC STUPOR & COMA, COMA <1 HR W CC     -0.401389   0.00425694
# 857 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION...  -0.44736   0.00429765
# 494 - LOWER EXTREM & HUMER PROC EXCEPT HIP,FOOT... -0.398778    0.0045375
# 025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR... -0.393906   0.00510461
# 438 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W... -0.401354   0.00517284
# 580 - OTHER SKIN, SUBCUT TISS & BREAST PROC W CC   -0.460619   0.00536037
# 125 - OTHER DISORDERS OF THE EYE W/O MCC           -0.799692   0.00548752
# 027 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR... -0.391755   0.00589383
# 196 - INTERSTITIAL LUNG DISEASE W MCC              -0.489443   0.00605033
# 073 - CRANIAL & PERIPHERAL NERVE DISORDERS W MCC    -0.46729   0.00611012
# 054 - NERVOUS SYSTEM NEOPLASMS W MCC               -0.397923   0.00678887
# 336 - PERITONEAL ADHESIOLYSIS W CC                 -0.396982   0.00693304
# 239 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP... -0.447162    0.0070774
# 472 - CERVICAL SPINAL FUSION W CC                   -0.37231   0.00775611
# 038 - EXTRACRANIAL PROCEDURES W CC                 -0.376399   0.00911666
# 205 - OTHER RESPIRATORY SYSTEM DIAGNOSES W MCC     -0.441945    0.0100238
# 463 - WND DEBRID & SKN GRFT EXC HAND, FOR MUSCU... -0.486565    0.0100647
# 907 - OTHER O.R. PROCEDURES FOR INJURIES W MCC     -0.388253      0.01009
# 435 - MALIGNANCY OF HEPATOBILIARY SYSTEM OR PAN...  -0.36224    0.0105356
# 175 - PULMONARY EMBOLISM W MCC                      -0.35824    0.0114897
# 026 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR... -0.372844    0.0116551
# 856 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION... -0.418896    0.0122589
# ...                                                      ...          ...
# 023 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS... -0.322906    0.0325255
# 003 - ECMO OR TRACH W MV 96+ HRS OR PDX EXC FAC... -0.308613    0.0348072
# 571 - SKIN DEBRIDEMENT W CC                        -0.546791    0.0349214
# 041 - PERIPH/CRANIAL NERVE & OTHER NERV SYST PR...  -0.36823    0.0349893
# 167 - OTHER RESP SYSTEM O.R. PROCEDURES W CC        -0.31491    0.0351199
# 439 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W CC -0.298345    0.0353395
# 947 - SIGNS & SYMPTOMS W MCC                       -0.328161    0.0362004
# 024 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS... -0.448514    0.0362938
# 809 - MAJOR HEMATOL/IMMUN DIAG EXC SICKLE CELL ... -0.298661    0.0371155
# 032 - VENTRICULAR SHUNT PROCEDURES W CC            -0.456971    0.0372887
# 657 - KIDNEY & URETER PROCEDURES FOR NEOPLASM W CC -0.301387    0.0373696
# 155 - OTHER EAR, NOSE, MOUTH & THROAT DIAGNOSES... -0.580352    0.0375764
# 956 - LIMB REATTACHMENT, HIP & FEMUR PROC FOR M... -0.409704    0.0376552
# 225 - CARDIAC DEFIB IMPLANT W CARDIAC CATH W/O ... -0.733804    0.0382433
# 515 - OTHER MUSCULOSKELET SYS & CONN TISS O.R. ... -0.516474     0.040534
# 379 - G.I. HEMORRHAGE W/O CC/MCC                   -0.289749    0.0412483
# 556 - SIGNS & SYMPTOMS OF MUSCULOSKELETAL SYSTE... -0.305341    0.0413852
# 221 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR... -0.307554    0.0422679
# 250 - PERC CARDIOVASC PROC W/O CORONARY ARTERY ... -0.304022     0.042317
# 226 - CARDIAC DEFIBRILLATOR IMPLANT W/O CARDIAC... -0.378415    0.0429529
# 415 - CHOLECYSTECTOMY EXCEPT BY LAPAROSCOPE W/O... -0.525122    0.0444253
# 433 - CIRRHOSIS & ALCOHOLIC HEPATITIS W CC         -0.388361    0.0453003
# 357 - OTHER DIGESTIVE SYSTEM O.R. PROCEDURES W CC  -0.325762    0.0459488
# 217 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR... -0.320283    0.0468341
# 229 - OTHER CARDIOTHORACIC PROCEDURES W CC         -0.437854    0.0471256
# 867 - OTHER INFECTIOUS & PARASITIC DISEASES DIA... -0.417775    0.0472972
# 552 - MEDICAL BACK PROBLEMS W/O MCC                 -0.27836    0.0479408
# 432 - CIRRHOSIS & ALCOHOLIC HEPATITIS W MCC        -0.302396    0.0487325
# 313 - CHEST PAIN                                   -0.276286     0.049699
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...  -0.27613     0.049833
#
#                                                            m  m_floor  \
# 742 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ...  -5.39269     -6.0
# 091 - OTHER DISORDERS OF NERVOUS SYSTEM W MCC        -3.6014     -4.0
# 743 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ...  -2.68923     -3.0
# 982 - EXTENSIVE O.R. PROCEDURE UNRELATED TO PRI...  -4.74802     -5.0
# 620 - O.R. PROCEDURES FOR OBESITY W CC                -4.358     -5.0
# 406 - PANCREAS, LIVER & SHUNT PROCEDURES W CC       -6.00688     -7.0
# 375 - DIGESTIVE MALIGNANCY W CC                     -2.29945     -3.0
# 240 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP...  -7.39799     -8.0
# 086 - TRAUMATIC STUPOR & COMA, COMA <1 HR W CC      -2.24044     -3.0
# 857 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION...  -5.04127     -6.0
# 494 - LOWER EXTREM & HUMER PROC EXCEPT HIP,FOOT...    -2.551     -3.0
# 025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...  -8.15203     -9.0
# 438 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W...  -2.88911     -3.0
# 580 - OTHER SKIN, SUBCUT TISS & BREAST PROC W CC    -4.97706     -5.0
# 125 - OTHER DISORDERS OF THE EYE W/O MCC            -6.28214     -7.0
# 027 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...  -4.15033     -5.0
# 196 - INTERSTITIAL LUNG DISEASE W MCC               -5.37704     -6.0
# 073 - CRANIAL & PERIPHERAL NERVE DISORDERS W MCC    -3.37229     -4.0
# 054 - NERVOUS SYSTEM NEOPLASMS W MCC                -3.00204     -4.0
# 336 - PERITONEAL ADHESIOLYSIS W CC                  -3.78968     -4.0
# 239 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP...  -12.6325    -13.0
# 472 - CERVICAL SPINAL FUSION W CC                   -4.61892     -5.0
# 038 - EXTRACRANIAL PROCEDURES W CC                  -2.97052     -3.0
# 205 - OTHER RESPIRATORY SYSTEM DIAGNOSES W MCC      -5.62898     -6.0
# 463 - WND DEBRID & SKN GRFT EXC HAND, FOR MUSCU...  -27.6547    -28.0
# 907 - OTHER O.R. PROCEDURES FOR INJURIES W MCC      -6.81721     -7.0
# 435 - MALIGNANCY OF HEPATOBILIARY SYSTEM OR PAN...  -3.15263     -4.0
# 175 - PULMONARY EMBOLISM W MCC                      -2.55539     -3.0
# 026 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...  -5.56822     -6.0
# 856 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION...  -11.0156    -12.0
# ...                                                      ...      ...
# 023 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS...  -11.8882    -12.0
# 003 - ECMO OR TRACH W MV 96+ HRS OR PDX EXC FAC...  -23.7251    -24.0
# 571 - SKIN DEBRIDEMENT W CC                         -3.18146     -4.0
# 041 - PERIPH/CRANIAL NERVE & OTHER NERV SYST PR...  -5.30803     -6.0
# 167 - OTHER RESP SYSTEM O.R. PROCEDURES W CC        -2.55462     -3.0
# 439 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W CC  -1.30733     -2.0
# 947 - SIGNS & SYMPTOMS W MCC                        -2.56484     -3.0
# 024 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS...   -9.1144    -10.0
# 809 - MAJOR HEMATOL/IMMUN DIAG EXC SICKLE CELL ...  -1.73594     -2.0
# 032 - VENTRICULAR SHUNT PROCEDURES W CC             -4.99684     -5.0
# 657 - KIDNEY & URETER PROCEDURES FOR NEOPLASM W CC  -3.49741     -4.0
# 155 - OTHER EAR, NOSE, MOUTH & THROAT DIAGNOSES...  -4.11271     -5.0
# 956 - LIMB REATTACHMENT, HIP & FEMUR PROC FOR M...  -15.5754    -16.0
# 225 - CARDIAC DEFIB IMPLANT W CARDIAC CATH W/O ...  -25.4485    -26.0
# 515 - OTHER MUSCULOSKELET SYS & CONN TISS O.R. ...  -14.9255    -15.0
# 379 - G.I. HEMORRHAGE W/O CC/MCC                   -0.971889     -1.0
# 556 - SIGNS & SYMPTOMS OF MUSCULOSKELETAL SYSTE...  -1.35634     -2.0
# 221 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR...  -6.11465     -7.0
# 250 - PERC CARDIOVASC PROC W/O CORONARY ARTERY ...  -5.39068     -6.0
# 226 - CARDIAC DEFIBRILLATOR IMPLANT W/O CARDIAC...  -13.5175    -14.0
# 415 - CHOLECYSTECTOMY EXCEPT BY LAPAROSCOPE W/O...  -8.83273     -9.0
# 433 - CIRRHOSIS & ALCOHOLIC HEPATITIS W CC          -2.71897     -3.0
# 357 - OTHER DIGESTIVE SYSTEM O.R. PROCEDURES W CC   -4.42516     -5.0
# 217 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR...   -9.2239    -10.0
# 229 - OTHER CARDIOTHORACIC PROCEDURES W CC           -12.839    -13.0
# 867 - OTHER INFECTIOUS & PARASITIC DISEASES DIA...  -7.83553     -8.0
# 552 - MEDICAL BACK PROBLEMS W/O MCC                 -1.08069     -2.0
# 432 - CIRRHOSIS & ALCOHOLIC HEPATITIS W MCC         -2.59135     -3.0
# 313 - CHEST PAIN                                   -0.916631     -1.0
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...  -1.18675     -2.0
#
#                                                     cost_rank
# 742 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ...        306
# 091 - OTHER DISORDERS OF NERVOUS SYSTEM W MCC             243
# 743 - UTERINE & ADNEXA PROC FOR NON-MALIGNANCY ...        147
# 982 - EXTENSIVE O.R. PROCEDURE UNRELATED TO PRI...        413
# 620 - O.R. PROCEDURES FOR OBESITY W CC                    313
# 406 - PANCREAS, LIVER & SHUNT PROCEDURES W CC             434
# 375 - DIGESTIVE MALIGNANCY W CC                           179
# 240 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP...        391
# 086 - TRAUMATIC STUPOR & COMA, COMA <1 HR W CC            156
# 857 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION...        349
# 494 - LOWER EXTREM & HUMER PROC EXCEPT HIP,FOOT...        236
# 025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...        483
# 438 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W...        279
# 580 - OTHER SKIN, SUBCUT TISS & BREAST PROC W CC          276
# 125 - OTHER DISORDERS OF THE EYE W/O MCC                   51
# 027 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...        393
# 196 - INTERSTITIAL LUNG DISEASE W MCC                     280
# 073 - CRANIAL & PERIPHERAL NERVE DISORDERS W MCC          202
# 054 - NERVOUS SYSTEM NEOPLASMS W MCC                      222
# 336 - PERITONEAL ADHESIOLYSIS W CC                        371
# 239 - AMPUTATION FOR CIRC SYS DISORDERS EXC UPP...        485
# 472 - CERVICAL SPINAL FUSION W CC                         412
# 038 - EXTRACRANIAL PROCEDURES W CC                        246
# 205 - OTHER RESPIRATORY SYSTEM DIAGNOSES W MCC            299
# 463 - WND DEBRID & SKN GRFT EXC HAND, FOR MUSCU...        519
# 907 - OTHER O.R. PROCEDURES FOR INJURIES W MCC            478
# 435 - MALIGNANCY OF HEPATOBILIARY SYSTEM OR PAN...        308
# 175 - PULMONARY EMBOLISM W MCC                            210
# 026 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL PR...        439
# 856 - POSTOPERATIVE OR POST-TRAUMATIC INFECTION...        498
# ...                                                       ...
# 023 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS...        515
# 003 - ECMO OR TRACH W MV 96+ HRS OR PDX EXC FAC...        559
# 571 - SKIN DEBRIDEMENT W CC                               187
# 041 - PERIPH/CRANIAL NERVE & OTHER NERV SYST PR...        387
# 167 - OTHER RESP SYSTEM O.R. PROCEDURES W CC              319
# 439 - DISORDERS OF PANCREAS EXCEPT MALIGNANCY W CC        100
# 947 - SIGNS & SYMPTOMS W MCC                              189
# 024 - CRANIO W MAJOR DEV IMPL/ACUTE COMPLEX CNS...        480
# 809 - MAJOR HEMATOL/IMMUN DIAG EXC SICKLE CELL ...        165
# 032 - VENTRICULAR SHUNT PROCEDURES W CC                   351
# 657 - KIDNEY & URETER PROCEDURES FOR NEOPLASM W CC        357
# 155 - OTHER EAR, NOSE, MOUTH & THROAT DIAGNOSES...        108
# 956 - LIMB REATTACHMENT, HIP & FEMUR PROC FOR M...        509
# 225 - CARDIAC DEFIB IMPLANT W CARDIAC CATH W/O ...        526
# 515 - OTHER MUSCULOSKELET SYS & CONN TISS O.R. ...        440
# 379 - G.I. HEMORRHAGE W/O CC/MCC                           16
# 556 - SIGNS & SYMPTOMS OF MUSCULOSKELETAL SYSTE...         62
# 221 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR...        490
# 250 - PERC CARDIOVASC PROC W/O CORONARY ARTERY ...        466
# 226 - CARDIAC DEFIBRILLATOR IMPLANT W/O CARDIAC...        538
# 415 - CHOLECYSTECTOMY EXCEPT BY LAPAROSCOPE W/O...        272
# 433 - CIRRHOSIS & ALCOHOLIC HEPATITIS W CC                134
# 357 - OTHER DIGESTIVE SYSTEM O.R. PROCEDURES W CC         375
# 217 - CARDIAC VALVE & OTH MAJ CARDIOTHORACIC PR...        523
# 229 - OTHER CARDIOTHORACIC PROCEDURES W CC                504
# 867 - OTHER INFECTIOUS & PARASITIC DISEASES DIA...        418
# 552 - MEDICAL BACK PROBLEMS W/O MCC                        67
# 432 - CIRRHOSIS & ALCOHOLIC HEPATITIS W MCC               277
# 313 - CHEST PAIN                                           22
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...         75
#
# [95 rows x 11 columns]

# %%
# example grpah of the DRG with the most negative m

sample_DRG = sig_HHI_by_DRG[sig_HHI_by_DRG == sig_HHI_by_DRG.m.min()].index[0]
sample_DRG_df = state_cost_df[state_cost_df['DRG Definition'] == sample_DRG]

x = sample_DRG_df.HHI
y = sample_DRG_df[acc]
m, b, r, p, e = stats.linregress(sample_DRG_df.HHI, sample_DRG_df[acc])

plt.scatter(x, y)
x_line = np.array([x.min(), x.max()])
y_line = m * x_line + b
plt.plot(x_line, y_line, '--k')
plt.text(7500, 900000, "$m={:.3f}$".format(m))
plt.text(7500, 950000, "$R^2={:.3f}$".format(r*r))
plt.text(7500, 850000, "$p={:.3f}$".format(p))
plt.title("HHI vs. ACC for most negative M")
plt.show()

# %% [markdown]
# Interesting. All the significant regressions showed a negative m...! Suggesting that less competetive insurance industries lead to higher charged costs from hospitals!

# %% [markdown]
# ### Next steps:
# * a more formal assessment of whether a provider who charges more or less for one DRG is likely to charge more or less for other DRGs
# * assessing relationship between ACC and population within each HRR or percentage of population on medicare
# * doing the appropriate statistical tests to see whether teaching hospitals charge more / less than non-teaching hospitals for particular DRG's in particular regions.
# * some multivariate regressions combining the above variables (i.e. population on medicare, total population, number of providers per HRR, competitiveness of private insurance market)
